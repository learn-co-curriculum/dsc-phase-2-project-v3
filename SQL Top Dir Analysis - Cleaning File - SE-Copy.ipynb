# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# ![SQL%20Schem.png](attachment:SQL%20Schem.png)

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns
import matplotlib.ticker as ticker
from matplotlib.ticker import StrMethodFormatter

# %%
# Connect these


# movie_basics: df_a
# movie_id (key)
# primary_title
# runtime_minutes
# genres

# directors: df_b
# movie_id (key)
# person_id
# movie_id

# Persons: df_e
# person_id (key)
# primary_name
# death_year (exclude those who have died)

# pd.read_csv('zippedData/tn.movie_budgets.csv.gz'):
# movie (key) -- Clean the heck out of it
# production_budget
# domestic_gross
# worldwide_gross

# %%
conn = sqlite3.connect('data/im.db')

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type='table'")

# %%
table_names = cur.fetchall()

# %%
for name in table_names:
    print(name[0])
# Out:
# movie_basics
# directors
# known_for
# movie_akas
# movie_ratings
# persons
# principals
# writers
# movie_budge_table
# title
# movie_gross_table

# %%
conn.close()

# %%
conn = sqlite3.connect('data/im.db')

# %%
a = """
SELECT DISTINCT
*
FROM movie_basics
ORDER BY movie_id

"""

b = """
SELECT *
FROM directors

"""

c = """
SELECT *
FROM known_for

"""


d = """
SELECT *
FROM movie_akas

"""


e = """
SELECT *
FROM movie_ratings

"""



f = """
SELECT *
FROM persons

"""


g = """
SELECT *
FROM principals

"""


h = """
SELECT *
FROM writers

"""

# %%
df_a = pd.read_sql(a,conn)

# %%
df_b = pd.read_sql(b,conn)

# %%
df_c = pd.read_sql(c,conn)

# %%
df_d = pd.read_sql(d,conn)

# %%
df_e = pd.read_sql(e,conn)

# %%
df_f = pd.read_sql(f,conn)

# %%
df_g = pd.read_sql(g,conn)

# %%
df_h = pd.read_sql(h,conn)

# %%
df_a.head()
# Out:
#     movie_id                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy

# %%
df_b.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
df_c.head()
# Out:
#    person_id   movie_id
# 0  nm0061671  tt0837562
# 1  nm0061671  tt2398241
# 2  nm0061671  tt0844471
# 3  nm0061671  tt0118553
# 4  nm0061865  tt0896534

# %%
d = """
SELECT *
FROM movie_akas
WHERE attributes <> 'None'
"""

df_d = pd.read_sql(d,conn)

# %%
df_d.head(40)
# Out:
#       movie_id  ordering                                              title  \
# 0    tt0369610        13                            O Mundo dos Dinossauros
# 1    tt0369610        21                                  Jurassic World 3D
# 2    tt0369610        22                                  Jurassic World 3D
# 3    tt0369610        23                                  Jurassic World 3D
# 4    tt0369610         2                                           Ebb Tide
# 5    tt0369610        35                                    Jurassic Park 4
# 6    tt0369610        44                                    Jurassic Park 4
# 7    tt0369610         7                                     Mundo Jurásico
# 8    tt0369610         8                                  Jurassic World 3D
# 9    tt0401729        14                              John Carter Maaveeran
# 10   tt0401729        22               John Carter - Anamesa se dyo kosmous
# 11   tt0401729        24                            John Carter Mahaveerudu
# 12   tt0401729        34                      John Carter: Entre dos mundos
# 13   tt0401729         5                                            Barsoom
# 14  tt10121294         2  This Jelly Doughnut Feeling Ich fühl mich Berl...
# 15   tt1014759        23         Alice in Wonderland: An IMAX 3D Experience
# 16   tt1014759         2                       Alice Csodaországban IMAX 3D
# 17   tt1014759        31                     I Aliki sti hora ton thavmaton
# 18   tt1014759        35                                Alice i eventyrland
# 19   tt1014759         6                                              Alice
# 20  tt10351180         3                                            Bad Boy
# 21   tt1179034         2                             Apo to Parisi me agapi
# 22   tt1194173        19                            I klironomia tou Bourne
# 23   tt1194173         2                                            Marcher
# 24   tt1219289        32                                      Apolyti efyia
# 25   tt1223236         6                                   Félins d'Afrique
# 26   tt1227927         1                                Anruf aus der Hölle
# 27   tt1227927         4                                  Caller ID: Entity
# 28   tt1233259         1                  Prince Killian and the Holy Grail
# 29   tt1233259         5                  Prince Killian and the Holy Grail
# 30   tt1280013         2                                          Mind Game
# 31   tt1294226        26                              To teleftaio tragoudi
# 32   tt1305797         1                                               Robo
# 33   tt1305797         4                                              Robot
# 34   tt1305797         9                                              Robot
# 35   tt1308729        13                                        El Ejecutor
# 36   tt1308729         1                                        El ejecutor
# 37   tt1308729        28                                        El ejecutor
# 38   tt1309561         2                                             Lamhaa
# 39   tt1322257         6                                        Call Me Dil
#
#    region language types                        attributes  is_original_title
# 0      BR     None  None                       short title                0.0
# 1      US     None  None                       3-D version                0.0
# 2      DE     None  None                       3-D version                0.0
# 3     XWW     None  None                       3-D version                0.0
# 4      US     None  None                fake working title                0.0
# 5      TR       tr  None        informal alternative title                0.0
# 6      US     None  None        informal alternative title                0.0
# 7      UY     None  None                       3-D version                0.0
# 8      PL     None  None                       3-D version                0.0
# 9      IN       ta  None                    dubbed version                0.0
# 10     GR     None  None  transliterated ISO-LATIN-1 title                0.0
# 11     IN       te  None                    dubbed version                0.0
# 12     UY     None  None                       3-D version                0.0
# 13     US     None  None                fake working title                0.0
# 14     DE     None  None             original script title                0.0
# 15     US     None  None                      IMAX version                0.0
# 16     HU     None  None                      IMAX version                0.0
# 17     GR     None  None  transliterated ISO-LATIN-1 title                0.0
# 18     NO     None  None                    dubbed version                0.0
# 19     US     None  None             original script title                0.0
# 20    XWW     None  None              alternative spelling                0.0
# 21     GR     None  None  transliterated ISO-LATIN-1 title                0.0
# 22     GR     None  None  transliterated ISO-LATIN-1 title                0.0
# 23     US     None  None                fake working title                0.0
# 24     GR     None  None  transliterated ISO-LATIN-1 title                0.0
# 25     CA       fr  None                    dubbed version                0.0
# 26     DE     None  None                     DVD box title                0.0
# 27     US     None  None                         new title                0.0
# 28     CA       en  None                     DVD box title                0.0
# 29     US     None  None                     DVD box title                0.0
# 30     JP       en  None                     DVD box title                0.0
# 31     GR     None  None  transliterated ISO-LATIN-1 title                0.0
# 32     IN       te  None                     literal title                0.0
# 33     IN       hi  None                    dubbed version                0.0
# 34     US     None  None             literal English title                0.0
# 35     VE     None  None       alternative transliteration                0.0
# 36     CO     None  None                         new title                0.0
# 37     UY     None  None                    dubbed version                0.0
# 38     IN       hi  None                       short title                0.0
# 39     IN       hi  None              alternative spelling                0.0

# %%
df_e.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
df_f.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
df_g.head()
# Out:
#     movie_id  ordering  person_id  category       job        characters
# 0  tt0111414         1  nm0246005     actor      None       ["The Man"]
# 1  tt0111414         2  nm0398271  director      None              None
# 2  tt0111414         3  nm3739909  producer  producer              None
# 3  tt0323808        10  nm0059247    editor      None              None
# 4  tt0323808         1  nm3579312   actress      None  ["Beth Boothby"]

# %%
df_h.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0438973  nm0175726
# 2  tt0438973  nm1802864
# 3  tt0462036  nm1940585
# 4  tt0835418  nm0310087

# %%
df_check = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
df_check.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
df_check.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t')
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# 0                   Action and Adventure|Classics|Drama    William Friedkin
# 1                     Drama|Science Fiction and Fantasy    David Cronenberg
# 2                     Drama|Musical and Performing Arts      Allison Anders
# 3                            Drama|Mystery and Suspense      Barry Levinson
# 4                                         Drama|Romance      Rodney Bennett
# ...                                                 ...                 ...
# 1555   Action and Adventure|Horror|Mystery and Suspense                 NaN
# 1556                 Comedy|Science Fiction and Fantasy        Steve Barron
# 1557  Classics|Comedy|Drama|Musical and Performing Arts      Gordon Douglas
# 1558    Comedy|Drama|Kids and Family|Sports and Fitness  David Mickey Evans
# 1559  Action and Adventure|Art House and Internation...                 NaN
#
#                                                 writer  theater_date  \
# 0                                       Ernest Tidyman   Oct 9, 1971
# 1                         David Cronenberg|Don DeLillo  Aug 17, 2012
# 2                                       Allison Anders  Sep 13, 1996
# 3                      Paul Attanasio|Michael Crichton   Dec 9, 1994
# 4                                         Giles Cooper           NaN
# ...                                                ...           ...
# 1555                                               NaN  Aug 18, 2006
# 1556  Terry Turner|Tom Davis|Dan Aykroyd|Bonnie Turner  Jul 23, 1993
# 1557                                               NaN   Jan 1, 1962
# 1558                  David Mickey Evans|Robert Gunter   Apr 1, 1993
# 1559                                        Luc Besson  Sep 27, 2001
#
#           dvd_date currency  box_office      runtime             studio
# 0     Sep 25, 2001      NaN         NaN  104 minutes                NaN
# 1      Jan 1, 2013        $     600,000  108 minutes  Entertainment One
# 2     Apr 18, 2000      NaN         NaN  116 minutes                NaN
# 3     Aug 27, 1997      NaN         NaN  128 minutes                NaN
# 4              NaN      NaN         NaN  200 minutes                NaN
# ...            ...      ...         ...          ...                ...
# 1555   Jan 2, 2007        $  33,886,034  106 minutes    New Line Cinema
# 1556  Apr 17, 2001      NaN         NaN   88 minutes  Paramount Vantage
# 1557  May 11, 2004      NaN         NaN  111 minutes                NaN
# 1558  Jan 29, 2002      NaN         NaN  101 minutes                NaN
# 1559  Feb 11, 2003      NaN         NaN   94 minutes  Columbia Pictures
#
# [1560 rows x 12 columns]

# %%
pd.read_csv('zippedData/rt.reviews.tsv.gz', delimiter='\t', encoding='ISO-8859-1')
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
#                   critic  top_critic         publisher                date
# 0             PJ Nabarro           0   Patrick Nabarro   November 10, 2018
# 1         Annalee Newitz           0           io9.com        May 23, 2018
# 2           Sean Axmaker           0  Stream on Demand     January 4, 2018
# 3          Daniel Kasman           0              MUBI   November 16, 2017
# 4                    NaN           0      Cinema Scope    October 12, 2017
# ...                  ...         ...               ...                 ...
# 54427      Laura Sinagra           1     Village Voice  September 24, 2002
# 54428  Michael Szymanski           0        Zap2it.com  September 21, 2005
# 54429       Emanuel Levy           0   EmanuelLevy.Com       July 17, 2005
# 54430   Christopher Null           0    Filmcritic.com   September 7, 2003
# 54431    Nicolas Lacroix           0      Showbizz.net   November 12, 2002
#
# [54432 rows x 8 columns]

# %%
pd.read_csv('zippedData/tmdb.movies.csv.gz')
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                          How to Train Your Dragon      28.734   2010-03-26
# 2                                        Iron Man 2      28.515   2010-05-07
# 3                                         Toy Story      28.005   1995-11-22
# 4                                         Inception      27.920   2010-07-16
# ...                                             ...         ...          ...
# 26512                         Laboratory Conditions       0.600   2018-10-13
# 26513                               _EXHIBIT_84xxx_       0.600   2018-05-01
# 26514                                  The Last One       0.600   2018-10-01
# 26515                                  Trailer Made       0.600   2018-06-22
# 26516                                    The Church       0.600   2018-10-05
#
#                                               title  vote_average  vote_count
# 0      Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                          How to Train Your Dragon           7.7        7610
# 2                                        Iron Man 2           6.8       12368
# 3                                         Toy Story           7.9       10174
# 4                                         Inception           8.3       22186
# ...                                             ...           ...         ...
# 26512                         Laboratory Conditions           0.0           1
# 26513                               _EXHIBIT_84xxx_           0.0           1
# 26514                                  The Last One           0.0           1
# 26515                                  Trailer Made           0.0           1
# 26516                                    The Church           0.0           1
#
# [26517 rows x 10 columns]

# %%
pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# 1         $410,600,000   $241,063,875  $1,045,663,875
# 2         $350,000,000    $42,762,350    $149,762,350
# 3         $330,600,000   $459,005,868  $1,403,013,963
# 4         $317,000,000   $620,181,382  $1,316,721,747
# ...                ...            ...             ...
# 5777            $7,000             $0              $0
# 5778            $6,000        $48,482        $240,495
# 5779            $5,000         $1,338          $1,338
# 5780            $1,400             $0              $0
# 5781            $1,100       $181,041        $181,041
#
# [5782 rows x 6 columns]

# %%
gross_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
gross_df.to_sql('title', conn, if_exists='replace', index=False)

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('movie_basics',), ('directors',), ('known_for',), ('movie_akas',), ('movie_ratings',), ('persons',), ('principals',), ('writers',), ('movie_budge_table',), ('movie_gross_table',), ('title',)]

# %%
# Read the CSV file
movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# Create a connection to the SQLite database
conn = sqlite3.connect('data/im.db')

# Create a table from the movie_gross DataFrame
movie_gross.to_sql('movie_gross_table', conn, if_exists='replace', index=False)

# %%
# Create a connection to the SQLite database
conn = sqlite3.connect('data/im.db')

# Define the SQL query to join the two tables
sql_query = '''
    SELECT DISTINCT
        per.person_id AS person_id,
        per.primary_name,
        per.death_year,
        der.movie_id AS movie_id,
        mb.primary_title,
        mb.runtime_minutes,
        mb.genres,
        mr.averagerating,
        mr.numvotes,
        1 as count
    FROM persons per
    LEFT JOIN directors der 
        ON per.person_id = der.person_id
    LEFT JOIN movie_basics mb
        ON mb.movie_id = der.movie_id
    
    LEFT JOIN movie_ratings mr
        ON mb.movie_id = mr.movie_id
    
    ORDER BY person_id
'''


# Execute the SQL query and fetch the results
results_db = pd.read_sql(sql_query, conn)

# Close the database connection
conn.close()

# Print the column names in the joined table
print(results_db.columns)
# Out:
# Index(['person_id', 'primary_name', 'death_year', 'movie_id', 'primary_title',
#        'runtime_minutes', 'genres', 'averagerating', 'numvotes', 'count'],
#       dtype='object')

# %%
results_db = results_db[pd.isna(results_db['death_year'])]

# %%
results_db['death_year'].min()
# Out:
# nan

# %%
results_db.isnull().sum()
# Out:
# person_id              0
# primary_name           0
# death_year         85331
# movie_id               0
# primary_title          0
# runtime_minutes     8823
# genres               793
# averagerating          0
# numvotes               0
# count                  0
# dtype: int64

# %%
results_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85331 entries, 44 to 660916
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   person_id        85331 non-null  object
#  1   primary_name     85331 non-null  object
#  2   death_year       0 non-null      float64
#  3   movie_id         85331 non-null  object
#  4   primary_title    85331 non-null  object
#  5   runtime_minutes  76508 non-null  float64
#  6   genres           84538 non-null  object
#  7   averagerating    85331 non-null  float64
#  8   numvotes         85331 non-null  float64
#  9   count            85331 non-null  int64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 7.2+ MB

# %%
results_db = results_db.dropna(subset=['movie_id', 'averagerating'])

# %%
### Nulls will not be counted in function below - does calc with only nulls

agg_funcs = {
    'averagerating': 'mean',
    'numvotes': 'sum',
    'runtime_minutes': 'mean',
    'death_year': 'max',
    'count': 'sum',
    'primary_title': lambda x: ', '.join([str(i).strip().lower().replace('none', '').replace('nan', '').replace('  ', ' ') for i in x.unique()]),
'genres': lambda x: ', '.join([str(i).strip().lower().replace('none', '').replace('nan', '').replace('  ', ' ') for i in x.unique()]),


}


director_agg = results_db.groupby('primary_name').agg(agg_funcs)

# %%
director_agg['count'].max()
# Out:
# 39

# %%
director_agg = director_agg.sort_values('averagerating', ascending=False)

# %%
director_agg.head(40)
# Out:
#                          averagerating  numvotes  runtime_minutes  death_year  \
# primary_name
# Josh Lowell                   8.230000   11660.0       112.875000         NaN
# Peter Mortimer                8.230000   11660.0       112.875000         NaN
# Pauli Janhunen Calderón       8.200000     387.0        77.272727         NaN
# Paul Dugdale                  7.926667    4516.0        98.785714         NaN
# Marco Romano                  7.620000     247.0       156.800000         NaN
# Roger Lay Jr.                 7.564286     306.0        95.384615         NaN
# Shiboprosad Mukherjee         7.554545    5146.0       140.636364         NaN
# Nandita Roy                   7.554545    5146.0       140.636364         NaN
# Sergey A.                     7.441026    1511.0        62.102564         NaN
# Larry Rosen                   7.405882    1225.0        79.000000         NaN
# David Horn                    7.363636     447.0        97.857143         NaN
# Jon Brewer                    7.360000    1342.0       103.857143         NaN
# Kaushik Ganguly               7.338889    5290.0       123.133333         NaN
# Mahesh Manjrekar              7.300000    6288.0       138.272727         NaN
# Phil Grabsky                  7.250000     502.0        91.375000         NaN
# Sonia Anderson                7.245455    1678.0        70.545455         NaN
# Barry Avrich                  7.240000    1289.0       107.923077         NaN
# Alex Gibney                   7.215000   86647.0       114.700000         NaN
# James Erskine                 7.200000   11076.0        94.181818         NaN
# Bing Wang                     7.171429    1915.0       148.923077         NaN
# Antoinette Jadaone            7.160000    2139.0       107.300000         NaN
# Satish Rajwade                7.080000    3237.0       132.000000         NaN
# Graeme Duane                  7.050000     170.0        48.538462         NaN
# Anurag Kashyap                7.040000  126884.0       149.700000         NaN
# Fajar Nugros                  7.018182    3808.0       104.444444         NaN
# Gajendra Ahire                6.985714     524.0       106.545455         NaN
# William Winckler              6.980000     994.0       106.782609         NaN
# Lav Diaz                      6.976923    4132.0       236.307692         NaN
# Jun Lana                      6.933333    1024.0       114.583333         NaN
# Jason Paul Laxamana           6.912500     860.0       105.846154         NaN
# Werner Herzog                 6.910000   63152.0       100.625000         NaN
# Monty Tiwa                    6.900000    1456.0       101.600000         NaN
# Carlos Moreno                 6.880000    1689.0        95.857143         NaN
# Rosa von Praunheim            6.870000     553.0        84.888889         NaN
# Cathy Garcia-Molina           6.868750    5737.0       117.333333         NaN
# Dan Villegas                  6.850000    1244.0       104.583333         NaN
# Srijit Mukherji               6.826667   19910.0       137.000000         NaN
# Arindam Sil                   6.810000    4497.0       129.400000         NaN
# Victor Vu                     6.800000    2758.0       104.666667         NaN
# Guntur Soeharjanto            6.785714    1055.0       104.100000         NaN
#
#                          count  \
# primary_name
# Josh Lowell                 10
# Peter Mortimer              10
# Pauli Janhunen Calderón     11
# Paul Dugdale                15
# Marco Romano                10
# Roger Lay Jr.               14
# Shiboprosad Mukherjee       11
# Nandita Roy                 11
# Sergey A.                   39
# Larry Rosen                 34
# David Horn                  11
# Jon Brewer                  10
# Kaushik Ganguly             18
# Mahesh Manjrekar            12
# Phil Grabsky                16
# Sonia Anderson              11
# Barry Avrich                15
# Alex Gibney                 20
# James Erskine               11
# Bing Wang                   14
# Antoinette Jadaone          10
# Satish Rajwade              10
# Graeme Duane                14
# Anurag Kashyap              10
# Fajar Nugros                11
# Gajendra Ahire              14
# William Winckler            25
# Lav Diaz                    13
# Jun Lana                    12
# Jason Paul Laxamana         16
# Werner Herzog               10
# Monty Tiwa                  18
# Carlos Moreno               10
# Rosa von Praunheim          10
# Cathy Garcia-Molina         16
# Dan Villegas                12
# Srijit Mukherji             15
# Arindam Sil                 10
# Victor Vu                   10
# Guntur Soeharjanto          14
#
#                                                              primary_title  \
# primary_name
# Josh Lowell              reel rock 7, reel rock 8, reel rock 6, reel ro...
# Peter Mortimer           reel rock 7, reel rock 8, reel rock 6, reel ro...
# Pauli Janhunen Calderón  clank and goldscar, rinoplasticos: a warrior's...
# Paul Dugdale             the prodigy: world's on fire, emeli sandé live...
# Marco Romano             nothing, owl looked at the wet floor with deat...
# Roger Lay Jr.            toy masters, stardate revisited: the origin of...
# Shiboprosad Mukherjee    icche, muktodhara, alik sukh - a tale of fleet...
# Nandita Roy              icche, muktodhara, alik sukh - a tale of fleet...
# Sergey A.                forest of the dead sharks, watch movie free on...
# Larry Rosen              starting over, four leaf clover, forever yours...
# David Horn               tony bennett & lady gaga: cheek to cheek live!...
# Jon Brewer               b.b. king: the life of riley, nat king cole: a...
# Kaushik Ganguly          jyeshthoputro (the elder son), just another lo...
# Mahesh Manjrekar         city of gold - mumbai 1982: ek ankahee kahani,...
# Phil Grabsky             the boy mir, in search of haydn, leonardo live...
# Sonia Anderson           lady gaga: one sequin at a time, one direction...
# Barry Avrich             unauthorized: the harvey weinstein project, an...
# Alex Gibney              freakonomics, magic trip: ken kesey's search f...
# James Erskine            one night in turin, from the ashes, the battle...
# Bing Wang                the ditch, man with no name, three sisters, al...
# Antoinette Jadaone       six degrees of separation from lilia cuntapay,...
# Satish Rajwade           mumbai pune mumbai, premachi goshta, popat, sa...
# Graeme Duane             black mamba: kiss of death, lion brotherhood, ...
# Anurag Kashyap           that girl in yellow boots, gangs of wasseypur,...
# Fajar Nugros             cinta di saku celana, cinta brontosaurus, 7 ha...
# Gajendra Ahire           samudra, hello jaihind, paradh, touring talkie...
# William Winckler         ultraman zero: the revenge of belial, zombrex:...
# Lav Diaz                 ang hupa, century of birthing, elegy to the vi...
# Jun Lana                 my neighbor's wife, yesterday today tomorrow, ...
# Jason Paul Laxamana      between maybes, astro mayabang, the spider's l...
# Werner Herzog            nomad: in the footsteps of bruce chatwin, fami...
# Monty Tiwa               pohon terkenal, pocong the origin, laskar pemi...
# Carlos Moreno            one, the story of a goal, the snitch cartel, a...
# Rosa von Praunheim       new york memories, rent boys, könig des comics...
# Cathy Garcia-Molina      miss you like crazy, cinco, my amnesia girl, f...
# Dan Villegas             mayohan, english only, please, the breakup pla...
# Srijit Mukherji          vinci da, autograph, baishe srabon, hemlock so...
# Arindam Sil              aborto, ebar shabor, har har byomkesh, swade a...
# Victor Vu                inferno, battle of the brides, sword of the as...
# Guntur Soeharjanto       rumput tetangga, ngebut kawin, kabayan jadi mi...
#
#                                                                     genres
# primary_name
# Josh Lowell              documentary, documentary,sport, sport, adventu...
# Peter Mortimer           documentary, documentary,sport, sport, adventu...
# Pauli Janhunen Calderón  action, action,adventure,sci-fi, action,animat...
# Paul Dugdale              documentary, music, documentary,music, biography
# Marco Romano                   drama, horror,thriller, drama,horror,sci-fi
# Roger Lay Jr.                    biography,comedy,documentary, documentary
# Shiboprosad Mukherjee    drama, drama,family, comedy,drama,romance, com...
# Nandita Roy              drama, drama,family, comedy,drama,romance, com...
# Sergey A.                action,comedy,horror, action,adventure,comedy,...
# Larry Rosen              comedy,drama,romance, crime,thriller, horror, ...
# David Horn                                   music, musical, comedy, drama
# Jon Brewer               biography,documentary,music, documentary, docu...
# Kaushik Ganguly          drama, crime, drama,family,history, adventure,...
# Mahesh Manjrekar         crime,drama, action, comedy, drama,family,hist...
# Phil Grabsky             documentary, biography,documentary,music, biog...
# Sonia Anderson           documentary,music, biography,documentary, docu...
# Barry Avrich             biography,documentary, documentary, musical, d...
# Alex Gibney              documentary, biography,documentary,sport, docu...
# James Erskine            documentary,sport, biography,documentary,histo...
# Bing Wang                 drama, documentary, documentary,family, horror,
# Antoinette Jadaone       comedy,drama, comedy,romance, romance, drama,f...
# Satish Rajwade           drama,romance, romance, drama, comedy, comedy,...
# Graeme Duane                              documentary, documentary,history
# Anurag Kashyap           crime,drama,mystery, action,comedy,crime, dram...
# Fajar Nugros             comedy,drama, romance, drama, drama,romance, a...
# Gajendra Ahire                                 drama, action,drama, horror
# William Winckler         action,sci-fi, horror, animation, animation,sc...
# Lav Diaz                 sci-fi, drama, documentary, crime,drama, adven...
# Jun Lana                 drama, drama,romance, drama,history, comedy,ro...
# Jason Paul Laxamana      drama,romance, comedy, drama, romance, comedy,...
# Werner Herzog            documentary, drama, documentary,history, adven...
# Monty Tiwa               drama, horror, comedy,musical,war, comedy, com...
# Carlos Moreno            documentary, action,crime,drama, comedy,drama,...
# Rosa von Praunheim       documentary, comedy,documentary,romance, , bio...
# Cathy Garcia-Molina      drama,romance, comedy,drama,horror, comedy, dr...
# Dan Villegas             drama,romance, comedy, drama,music,romance, co...
# Srijit Mukherji          crime,mystery,thriller, drama, drama,mystery,t...
# Arindam Sil              drama, crime,mystery,thriller, action,thriller...
# Victor Vu                thriller, comedy, action,drama,history, drama,...
# Guntur Soeharjanto              comedy,drama, comedy, drama,romance, drama

# %%
# director_db = director_db.loc[director_db['rounded_avg_rating'] >= 8]

# %%
director_agg = director_agg.loc[director_agg['count'] >= 10]

# %%
director_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, Josh Lowell to Eldar Bogunov
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   averagerating    200 non-null    float64
#  1   numvotes         200 non-null    float64
#  2   runtime_minutes  200 non-null    float64
#  3   death_year       0 non-null      float64
#  4   count            200 non-null    int64
#  5   primary_title    200 non-null    object
#  6   genres           200 non-null    object
# dtypes: float64(4), int64(1), object(2)
# memory usage: 12.5+ KB

# %%
# Create a box plot of the 'averagerating' column
sns.boxplot(data=director_agg, y='averagerating')
# Out:
# <AxesSubplot:ylabel='averagerating'>

# %%
# Create a box plot of the 'averagerating' column
sns.boxplot(data=results_db, y='averagerating')
# Out:
# <AxesSubplot:ylabel='averagerating'>

# %%
# sns.set(style="ticks")

# # Create a box plot for each primary_name
# sns.catplot(x="primary_name", y="averagerating", kind="box", data=results_db)

# # Rotate x-axis labels
# plt.xticks(rotation=90)

# # Show the plot
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-130-bc9b20a5f60d> in <module>
#       2
#       3 # Create a box plot for each primary_name
# ----> 4 sns.catplot(x="primary_name", y="averagerating", kind="box", data=results_db)
#       5
#       6 # Rotate x-axis labels
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3832
#    3833     # Draw the plot onto the facets
# -> 3834     g.map_dataframe(plot_func, x=x, y=y, hue=hue, **plot_kws)
#    3835
#    3836     if p.orient == "h":
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     748
#     749             # Draw the plot
# --> 750             self._facet_plot(func, ax, args, kwargs)
#     751
#     752         # Finalize the annotations and layout
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     772                 plot_kwargs[key] = val
#     773             plot_args = []
# --> 774         func(*plot_args, **plot_kwargs)
#     775
#     776         # Sort out the supporting information
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py in boxplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, width, dodge, fliersize, linewidth, whis, ax, **kwargs)
#    2236     kwargs.update(dict(whis=whis))
#    2237
# -> 2238     plotter.plot(ax, kwargs)
#    2239     return ax
#    2240
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py in plot(self, ax, boxplot_kws)
#     507     def plot(self, ax, boxplot_kws):
#     508         """Make the plot."""
# --> 509         self.draw_boxplot(ax, boxplot_kws)
#     510         self.annotate_axes(ax)
#     511         if self.orient == "h":
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py in draw_boxplot(self, ax, kws)
#     446                                          **kws)
#     447                 color = self.colors[i]
# --> 448                 self.restyle_boxplot(artist_dict, color, props)
#     449             else:
#     450                 # Draw nested groups of boxes
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\categorical.py in restyle_boxplot(self, artist_dict, color, props)
#     499             med.update(props["median"])
#     500         for fly in artist_dict["fliers"]:
# --> 501             fly.update(dict(markerfacecolor=self.gray,
#     502                             marker="d",
#     503                             markeredgecolor=self.gray,
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\artist.py in update(self, props)
#     996                         raise AttributeError(f"{type(self).__name__!r} object "
#     997                                              f"has no property {k!r}")
# --> 998                     ret.append(func(v))
#     999         if ret:
#    1000             self.pchanged()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\lines.py in set_marker(self, marker)
#    1155             arguments.
#    1156         """
# -> 1157         self._marker.set_marker(marker)
#    1158         self.stale = True
#    1159
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     311         if not isinstance(marker, MarkerStyle):
#     312             self._marker = marker
# --> 313             self._recache()
#     314
#     315     def get_path(self):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\markers.py in _recache(self)
#     239         self._capstyle = 'butt'
#     240         self._filled = True
# --> 241         self._marker_function()
#     242
#     243     def __bool__(self):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\markers.py in _set_thin_diamond(self)
#     552
#     553     def _set_thin_diamond(self):
# --> 554         self._set_diamond()
#     555         self._transform.scale(0.6, 1.0)
#     556
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\markers.py in _set_diamond(self)
#     531
#     532     def _set_diamond(self):
# --> 533         self._transform = Affine2D().translate(-0.5, -0.5).rotate_deg(45)
#     534         self._snap_threshold = 5.0
#     535         fs = self.get_fillstyle()
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\transforms.py in rotate_deg(self, degrees)
#    1943         and :meth:`scale`.
#    1944         """
# -> 1945         return self.rotate(math.radians(degrees))
#    1946
#    1947     def rotate_around(self, x, y, theta):
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\transforms.py in rotate(self, theta)
#    1931         rotate_mtx = np.array([[a, -b, 0.0], [b, a, 0.0], [0.0, 0.0, 1.0]],
#    1932                               float)
# -> 1933         self._mtx = np.dot(rotate_mtx, self._mtx)
#    1934         self.invalidate()
#    1935         return self
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
director_agg = director_agg.head(20)

# %%
director_agg = director_agg.reset_index()

# %%
sns.set(style="whitegrid")

fig, ax = plt.subplots(figsize=(12,8))

sns.scatterplot(x="primary_name", y="averagerating", data=director_agg, ax=ax)

ax.set_title("Average Rating by Director", fontsize=18)
ax.set_xlabel("Director", fontsize=14)
ax.set_ylabel("Average Rating", fontsize=14)

plt.xticks(rotation=90)

plt.show()

# %%
sns.set(style="whitegrid")

fig, ax = plt.subplots(figsize=(12,8))

sns.scatterplot(x="primary_name", y="averagerating", data=director_agg, ax=ax)

ax.set_title("Average Rating by Director", fontsize=18)
ax.set_xlabel("Director", fontsize=14)
ax.set_ylabel("Average Rating", fontsize=14)

plt.xticks(rotation=90)

# Add counts as label for each point
for i in range(len(director_agg)):
    x = director_agg.index[i]
    y = director_agg.iloc[i]['averagerating']
    count = director_agg.iloc[i]['count']
    ax.text(i, y-0.2, count, ha="center", fontsize=12)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,8))

# Scatterplot
sns.scatterplot(x="primary_name", y="averagerating", data=director_agg, ax=ax)

# Set plot title and axis labels
ax.set_title("Average Rating by Director", fontsize=18)
ax.set_xlabel("Director", fontsize=14)
ax.set_ylabel("Average Rating", fontsize=14)

# Rotate x-axis labels for better visibility
plt.xticks(rotation=90)

# Create legend
handles = []
for i in range(len(director_agg)):
    name = director_agg.iloc[i]['primary_name']
    rating = director_agg.iloc[i]['averagerating']
    count = director_agg.iloc[i]['count']
    handles.append(ax.scatter([], [], label=f"{name}\nRating: {rating:.2f}\nCount: {count}", s=50))

# Move legend to the far right
plt.legend(handles=handles, title="Director Info", loc="center left", bbox_to_anchor=(1.02, 0.5))

plt.show()

# %%
director_agg.head(20)
# Out:
#                primary_name  averagerating  numvotes  runtime_minutes  \
# 0               Josh Lowell       8.230000   11660.0       112.875000
# 1            Peter Mortimer       8.230000   11660.0       112.875000
# 2   Pauli Janhunen Calderón       8.200000     387.0        77.272727
# 3              Paul Dugdale       7.926667    4516.0        98.785714
# 4              Marco Romano       7.620000     247.0       156.800000
# 5             Roger Lay Jr.       7.564286     306.0        95.384615
# 6     Shiboprosad Mukherjee       7.554545    5146.0       140.636364
# 7               Nandita Roy       7.554545    5146.0       140.636364
# 8                 Sergey A.       7.441026    1511.0        62.102564
# 9               Larry Rosen       7.405882    1225.0        79.000000
# 10               David Horn       7.363636     447.0        97.857143
# 11               Jon Brewer       7.360000    1342.0       103.857143
# 12          Kaushik Ganguly       7.338889    5290.0       123.133333
# 13         Mahesh Manjrekar       7.300000    6288.0       138.272727
# 14             Phil Grabsky       7.250000     502.0        91.375000
# 15           Sonia Anderson       7.245455    1678.0        70.545455
# 16             Barry Avrich       7.240000    1289.0       107.923077
# 17              Alex Gibney       7.215000   86647.0       114.700000
# 18            James Erskine       7.200000   11076.0        94.181818
# 19                Bing Wang       7.171429    1915.0       148.923077
#
#     death_year  count                                      primary_title  \
# 0          NaN     10  reel rock 7, reel rock 8, reel rock 6, reel ro...
# 1          NaN     10  reel rock 7, reel rock 8, reel rock 6, reel ro...
# 2          NaN     11  clank and goldscar, rinoplasticos: a warrior's...
# 3          NaN     15  the prodigy: world's on fire, emeli sandé live...
# 4          NaN     10  nothing, owl looked at the wet floor with deat...
# 5          NaN     14  toy masters, stardate revisited: the origin of...
# 6          NaN     11  icche, muktodhara, alik sukh - a tale of fleet...
# 7          NaN     11  icche, muktodhara, alik sukh - a tale of fleet...
# 8          NaN     39  forest of the dead sharks, watch movie free on...
# 9          NaN     34  starting over, four leaf clover, forever yours...
# 10         NaN     11  tony bennett & lady gaga: cheek to cheek live!...
# 11         NaN     10  b.b. king: the life of riley, nat king cole: a...
# 12         NaN     18  jyeshthoputro (the elder son), just another lo...
# 13         NaN     12  city of gold - mumbai 1982: ek ankahee kahani,...
# 14         NaN     16  the boy mir, in search of haydn, leonardo live...
# 15         NaN     11  lady gaga: one sequin at a time, one direction...
# 16         NaN     15  unauthorized: the harvey weinstein project, an...
# 17         NaN     20  freakonomics, magic trip: ken kesey's search f...
# 18         NaN     11  one night in turin, from the ashes, the battle...
# 19         NaN     14  the ditch, man with no name, three sisters, al...
#
#                                                genres
# 0   documentary, documentary,sport, sport, adventu...
# 1   documentary, documentary,sport, sport, adventu...
# 2   action, action,adventure,sci-fi, action,animat...
# 3    documentary, music, documentary,music, biography
# 4         drama, horror,thriller, drama,horror,sci-fi
# 5           biography,comedy,documentary, documentary
# 6   drama, drama,family, comedy,drama,romance, com...
# 7   drama, drama,family, comedy,drama,romance, com...
# 8   action,comedy,horror, action,adventure,comedy,...
# 9   comedy,drama,romance, crime,thriller, horror, ...
# 10                      music, musical, comedy, drama
# 11  biography,documentary,music, documentary, docu...
# 12  drama, crime, drama,family,history, adventure,...
# 13  crime,drama, action, comedy, drama,family,hist...
# 14  documentary, biography,documentary,music, biog...
# 15  documentary,music, biography,documentary, docu...
# 16  biography,documentary, documentary, musical, d...
# 17  documentary, biography,documentary,sport, docu...
# 18  documentary,sport, biography,documentary,histo...
# 19   drama, documentary, documentary,family, horror,

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-039c95285c7e> in <module>
#       1 color_dict = {}
#       2 for name in director_agg["primary_name"].unique():
# ----> 3     color_dict[name] = plt.cm.tab20(name)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\matplotlib\colors.py in __call__(self, X, alpha, bytes)
#     568             self._init()
#     569
# --> 570         mask_bad = X.mask if np.ma.is_masked(X) else np.isnan(X)  # Mask nan's.
#     571         xa = np.array(X, copy=True)
#     572         if not xa.dtype.isnative:
#
# TypeError: ufunc 'isnan' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
director_db = results_db.dropna(subset=['movie_id'])

# %%
director_db = director_db.dropna(subset=['averagerating','numvotes'])

# %%
director_db.isna().sum()
# Out:
# person_id              0
# primary_name           0
# death_year         85331
# movie_id               0
# primary_title          0
# runtime_minutes     8823
# genres               793
# averagerating          0
# numvotes               0
# count                  0
# dtype: int64

# %%
director_db = director_db.groupby('primary_name').sum()

# %%
# director_db = results_db.groupby('primary_name').sum()

# %%
director_db.tail(40)
# Out:
#                       death_year  runtime_minutes  averagerating  numvotes  \
# primary_name
# Ömer Vargi                   0.0            202.0           11.6    3900.0
# Ömür Atay                    0.0              0.0            6.3      64.0
# Önder K. Açikbas             0.0              0.0            2.8      16.0
# Öner S. Biberkökü            0.0            105.0            7.4      11.0
# Örn Marino Arnarson          0.0            150.0           15.8     111.0
# Öystein Thorsen              0.0              0.0            7.4       5.0
# Özay Kanat                   0.0             75.0            5.8      39.0
# Özcan Alper                  0.0            313.0           19.1    1388.0
# Özcan Deniz                  0.0            620.0           34.7   15278.0
# Özer Kiziltan                0.0            221.0           16.8     873.0
# Özgür Bakar                  0.0            572.0           49.8    2713.0
# Özgür Dogruöz                0.0              0.0            5.1     137.0
# Özgür Selvi                  0.0             85.0            5.8     209.0
# Özgür Sevimli                0.0             93.0            6.5      82.0
# Özgür Seyben                 0.0             83.0            5.4      29.0
# Özgür Yelence                0.0             82.0            3.3      97.0
# Özgür Yildirim               0.0            295.0           18.6    3640.0
# Özgür Özberk                 0.0            193.0            7.8     318.0
# Özhan Eren                   0.0            122.0            4.5     654.0
# Özkan Çelik                  0.0             81.0           11.3     456.0
# Özlem Akovaligil             0.0            112.0            7.0      28.0
# Özlem Kayhan                 0.0             90.0            5.3     254.0
# Özlem Koza                   0.0              0.0            6.6      40.0
# Özlem Sariyildiz             0.0             70.0            7.8      14.0
# Øystein Frøyland             0.0             60.0            9.0       7.0
# Øystein Karlsen              0.0            186.0           12.9     876.0
# Øystein Rakkenes             0.0             55.0            6.7       6.0
# Øystein Runde                0.0             72.0            7.8       6.0
# Øystein Stene                0.0             75.0            5.2     165.0
# Øyunn Gorset                 0.0            109.0            9.1      13.0
# Øyvind Sandberg              0.0             61.0            7.8      47.0
# Ülkü Oktay                   0.0             81.0            6.0      64.0
# Ülviyya Könül                0.0              0.0            8.7      13.0
# Ümit Cihan Canpolat          0.0             94.0            6.6      53.0
# Ümit Degirmenci              0.0            135.0            1.3     149.0
# Ümit Kivanç                  0.0            149.0           15.8     380.0
# Ümit Köreken                 0.0             94.0            6.4     351.0
# Ümit Uludag                  0.0             86.0            9.2      13.0
# Ümit Ünal                    0.0            371.0           23.8    3971.0
# Þórdur Bragi Jónsson         0.0             79.0            6.3      77.0
#
#                       count
# primary_name
# Ömer Vargi                2
# Ömür Atay                 1
# Önder K. Açikbas          1
# Öner S. Biberkökü         1
# Örn Marino Arnarson       2
# Öystein Thorsen           1
# Özay Kanat                1
# Özcan Alper               3
# Özcan Deniz               6
# Özer Kiziltan             3
# Özgür Bakar              12
# Özgür Dogruöz             1
# Özgür Selvi               2
# Özgür Sevimli             1
# Özgür Seyben              1
# Özgür Yelence             1
# Özgür Yildirim            3
# Özgür Özberk              2
# Özhan Eren                1
# Özkan Çelik               2
# Özlem Akovaligil          1
# Özlem Kayhan              1
# Özlem Koza                1
# Özlem Sariyildiz          1
# Øystein Frøyland          1
# Øystein Karlsen           2
# Øystein Rakkenes          1
# Øystein Runde             1
# Øystein Stene             1
# Øyunn Gorset              1
# Øyvind Sandberg           1
# Ülkü Oktay                1
# Ülviyya Könül             1
# Ümit Cihan Canpolat       1
# Ümit Degirmenci           1
# Ümit Kivanç               2
# Ümit Köreken              1
# Ümit Uludag               1
# Ümit Ünal                 4
# Þórdur Bragi Jónsson      1

# %%
director_db['avg_rating'] = director_db['averagerating'] / director_db['count']

# %%
director_db['avg_votes'] = director_db['numvotes'] / director_db['count']

# %%
director_db['avg_runtime'] = director_db['runtime_minutes'] / director_db['count']

# %%
director_db.drop(['runtime_minutes', 'averagerating', 'numvotes'], axis=1, inplace=True)

# %%
director_db['rounded_avg_rating'] = director_db['avg_rating'].round().astype(int)

# %%
director_db.head(40)
# Out:
#                       death_year  count  avg_rating    avg_votes  avg_runtime  \
# primary_name
# A Normale Jef                0.0      1    7.200000    31.000000        142.0
# A'Ali de Sousa               0.0      1    4.200000    55.000000         81.0
# A. Blaine Miller             0.0      1    7.000000     8.000000         78.0
# A. Cengiz Mert               0.0      1    3.200000     6.000000         89.0
# A. Fishman                   0.0      1    7.800000    37.000000         83.0
# A. Haluk Unal                0.0      1    8.800000     5.000000         80.0
# A. Jagadesh                  0.0      1    3.500000   291.000000        148.0
# A. Joji                      0.0      1    5.500000     6.000000        131.0
# A. Karunakaran               0.0      4    6.075000   824.750000        145.5
# A. Lawrence Dreyfuss         0.0      1    7.000000    17.000000         63.0
# A. Levent Ungor              0.0      1    5.200000    39.000000        110.0
# A. Liong Wong                0.0      1    5.100000    16.000000         80.0
# A. Mahadev                   0.0      1    5.800000   202.000000        153.0
# A. Majid                     0.0      1    3.200000     5.000000        115.0
# A. Rappaport                 0.0      1    7.600000    33.000000          0.0
# A. Razak Mohaideen           0.0      6    4.716667   119.500000         97.0
# A. Sarkunam                  0.0      4    5.725000   408.500000        135.0
# A. Sayeeda Moreno            0.0      1    8.400000     7.000000         84.0
# A. Senthil Kumar             0.0      1    3.700000    37.000000         95.0
# A. Taner Elhan               0.0      3    4.266667  1088.666667        103.0
# A. Todd Smith                0.0      2    6.900000   927.500000         92.0
# A. Uygur Ozturk              0.0      1    7.900000    16.000000         85.0
# A. Venkatesh                 0.0      6    4.316667    27.666667        112.0
# A.B. Sallu                   0.0      1    6.000000     6.000000          0.0
# A.B. Shawky                  0.0      1    7.100000   778.000000         97.0
# A.C. Mughil                  0.0      1    4.600000    21.000000          0.0
# A.D. Calvo                   0.0      5    5.120000   422.800000         85.8
# A.D. Freese                  0.0      1    8.400000    75.000000         99.0
# A.D. Gerhardt                0.0      1    4.600000     7.000000         92.0
# A.D. Liano                   0.0      1    6.500000     6.000000         90.0
# A.D. Oppenheim               0.0      1    7.800000     9.000000          0.0
# A.G. Amid                    0.0      1    7.700000  1059.000000        132.0
# A.J. Ager                    0.0      1    3.400000    17.000000        100.0
# A.J. Ali                     0.0      1    9.000000    24.000000         94.0
# A.J. Bond                    0.0      1    5.500000    87.000000         79.0
# A.J. Brooks                  0.0      1    4.000000     8.000000        110.0
# A.J. Detisch                 0.0      1    6.900000     8.000000         88.0
# A.J. Eaton                   0.0      1    6.700000    27.000000         95.0
# A.J. Edwards                 0.0      2    6.350000   672.500000         93.0
# A.J. Martinson               0.0      1    4.500000   207.000000         94.0
#
#                       rounded_avg_rating
# primary_name
# A Normale Jef                          7
# A'Ali de Sousa                         4
# A. Blaine Miller                       7
# A. Cengiz Mert                         3
# A. Fishman                             8
# A. Haluk Unal                          9
# A. Jagadesh                            4
# A. Joji                                6
# A. Karunakaran                         6
# A. Lawrence Dreyfuss                   7
# A. Levent Ungor                        5
# A. Liong Wong                          5
# A. Mahadev                             6
# A. Majid                               3
# A. Rappaport                           8
# A. Razak Mohaideen                     5
# A. Sarkunam                            6
# A. Sayeeda Moreno                      8
# A. Senthil Kumar                       4
# A. Taner Elhan                         4
# A. Todd Smith                          7
# A. Uygur Ozturk                        8
# A. Venkatesh                           4
# A.B. Sallu                             6
# A.B. Shawky                            7
# A.C. Mughil                            5
# A.D. Calvo                             5
# A.D. Freese                            8
# A.D. Gerhardt                          5
# A.D. Liano                             6
# A.D. Oppenheim                         8
# A.G. Amid                              8
# A.J. Ager                              3
# A.J. Ali                               9
# A.J. Bond                              6
# A.J. Brooks                            4
# A.J. Detisch                           7
# A.J. Eaton                             7
# A.J. Edwards                           6
# A.J. Martinson                         4

# %%
director_db = director_db.loc[director_db['rounded_avg_rating'] >= 8]

# %%
director_db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13445 entries, A. Fishman to Ümit Uludag
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   death_year          13445 non-null  float64
#  1   count               13445 non-null  int64
#  2   avg_rating          13445 non-null  float64
#  3   avg_votes           13445 non-null  float64
#  4   avg_runtime         13445 non-null  float64
#  5   rounded_avg_rating  13445 non-null  int32
# dtypes: float64(4), int32(1), int64(1)
# memory usage: 682.8+ KB

# %%
director_db.to_csv('joined_data.csv', index=False)

# %%
director_db = director_db.loc[director_db['count'] >= 10]

# %%
df1 = director_db.reset_index()

# Create a scatter plot of avg_rating vs primary_name
plt.scatter(df1['primary_name'], df1['rounded_avg_rating'])

# Set the x-axis label and rotate the tick labels to prevent overlapping
plt.xlabel('Primary Name')
plt.xticks(rotation=90)

# Set the y-axis label
plt.ylabel('rounded_avg_rating')

# Show the plot
plt.show()

# %%
sns.scatterplot(x='primary_name', y='avg_rating', data=director_db)

# Set the x-axis labels to be rotated
plt.xticks(rotation=90)

# Show the plot
plt.show()
