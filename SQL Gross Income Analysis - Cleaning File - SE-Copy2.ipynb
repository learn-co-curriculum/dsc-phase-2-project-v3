# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# ![SQL%20Schem.png](attachment:SQL%20Schem.png)

# %%
# Your code here - remember to use markdown cells for comments as well!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sqlite3
import seaborn as sns
import matplotlib.ticker as ticker
from matplotlib.ticker import StrMethodFormatter

# %%
conn = sqlite3.connect('data/im.db')

# %%
cur = conn.cursor()

# %%
cur.execute("SELECT name FROM sqlite_master WHERE type='table'")

# %%
table_names = cur.fetchall()

# %%
for name in table_names:
    print(name[0])
# Out:
# movie_basics
# directors
# known_for
# movie_akas
# movie_ratings
# persons
# principals
# writers
# title
# movie_gross_table

# %%
conn.close()

# %%
conn = sqlite3.connect('data/im.db')

# %%
a = """
SELECT DISTINCT
*
FROM movie_basics
ORDER BY primary_title

"""

b = """
SELECT *
FROM directors

"""

c = """
SELECT *
FROM known_for

"""


d = """
SELECT *
FROM movie_akas

"""


e = """
SELECT *
FROM movie_ratings

"""



f = """
SELECT *
FROM persons

"""


g = """
SELECT *
FROM principals

"""


h = """
SELECT *
FROM writers

"""

# %%
df_a = pd.read_sql(a,conn)

# %%
df_b = pd.read_sql(b,conn)

# %%
df_c = pd.read_sql(c,conn)

# %%
df_d = pd.read_sql(d,conn)

# %%
df_e = pd.read_sql(e,conn)

# %%
df_f = pd.read_sql(f,conn)

# %%
df_g = pd.read_sql(g,conn)

# %%
df_h = pd.read_sql(h,conn)

# %%
df_a.head()
# Out:
#     movie_id          primary_title        original_title  start_year  \
# 0  tt1699720  !Women Art Revolution  Women Art Revolution        2010
# 1  tt2346170       #1 Serial Killer      #1 Serial Killer        2013
# 2  tt3120962                     #5                    #5        2013
# 3  tt8219776                     #5                    #5        2018
# 4  tt4470336             #50Fathers            #50Fathers        2015
#
#    runtime_minutes                    genres
# 0             83.0               Documentary
# 1             87.0                    Horror
# 2             68.0  Biography,Comedy,Fantasy
# 3              NaN               Documentary
# 4            132.0                    Comedy

# %%
df_b.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
df_c.head()
# Out:
#    person_id   movie_id
# 0  nm0061671  tt0837562
# 1  nm0061671  tt2398241
# 2  nm0061671  tt0844471
# 3  nm0061671  tt0118553
# 4  nm0061865  tt0896534

# %%
d = """
SELECT *
FROM movie_akas
WHERE attributes <> 'None'
"""

df_d = pd.read_sql(d,conn)

# %%
df_d.head(40)
# Out:
#       movie_id  ordering                                              title  \
# 0    tt0369610        13                            O Mundo dos Dinossauros
# 1    tt0369610        21                                  Jurassic World 3D
# 2    tt0369610        22                                  Jurassic World 3D
# 3    tt0369610        23                                  Jurassic World 3D
# 4    tt0369610         2                                           Ebb Tide
# 5    tt0369610        35                                    Jurassic Park 4
# 6    tt0369610        44                                    Jurassic Park 4
# 7    tt0369610         7                                     Mundo Jurásico
# 8    tt0369610         8                                  Jurassic World 3D
# 9    tt0401729        14                              John Carter Maaveeran
# 10   tt0401729        22               John Carter - Anamesa se dyo kosmous
# ...

# %%
df_e.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
df_f.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
df_g.head()
# Out:
#     movie_id  ordering  person_id  category       job        characters
# 0  tt0111414         1  nm0246005     actor      None       ["The Man"]
# 1  tt0111414         2  nm0398271  director      None              None
# 2  tt0111414         3  nm3739909  producer  producer              None
# 3  tt0323808        10  nm0059247    editor      None              None
# 4  tt0323808         1  nm3579312   actress      None  ["Beth Boothby"]

# %%
df_h.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0438973  nm0175726
# 2  tt0438973  nm1802864
# 3  tt0462036  nm1940585
# 4  tt0835418  nm0310087

# %%
df_check = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
df_check.info()

# %%
df_check2 = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')

# %%
df_check2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
pd.read_csv('zippedData/rt.movie_info.tsv.gz', delimiter='\t')
# Out:
#         id                                           synopsis rating  \
# 0        1  This gritty, fast-paced, and innovative police...      R
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 2        5  Illeana Douglas delivers a superb performance ...      R
# 3        6  Michael Douglas runs afoul of a treacherous su...      R
# 4        7                                                NaN     NR
# ...    ...                                                ...    ...
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
# 1556  1997  The popular Saturday Night Live sketch was exp...     PG
# 1557  1998  Based on a novel by Richard Powell, when the l...      G
# 1558  1999  The Sandlot is a coming-of-age story about a g...     PG
# 1559  2000  Suspended from the force, Paris cop Hubert is ...      R
#
#                                                   genre            director  \
# ...

# %%
pd.read_csv('zippedData/rt.reviews.tsv.gz', delimiter='\t', encoding='ISO-8859-1')
# Out:
#          id                                             review rating   fresh  \
# 0         3  A distinctly gallows take on contemporary fina...    3/5   fresh
# 1         3  It's an allegory in search of a meaning that n...    NaN  rotten
# 2         3  ... life lived in a bubble in financial dealin...    NaN   fresh
# 3         3  Continuing along a line introduced in last yea...    NaN   fresh
# 4         3             ... a perverse twist on neorealism...     NaN   fresh
# ...     ...                                                ...    ...     ...
# 54427  2000  The real charm of this trifle is the deadpan c...    NaN   fresh
# 54428  2000                                                NaN    1/5  rotten
# 54429  2000                                                NaN    2/5  rotten
# 54430  2000                                                NaN  2.5/5  rotten
# 54431  2000                                                NaN    3/5   fresh
#
# ...

# %%
pd.read_csv('zippedData/tmdb.movies.csv.gz')
# Out:
#        Unnamed: 0            genre_ids      id original_language  \
# 0               0      [12, 14, 10751]   12444                en
# 1               1  [14, 12, 16, 10751]   10191                en
# 2               2        [12, 28, 878]   10138                en
# 3               3      [16, 35, 10751]     862                en
# 4               4        [28, 878, 12]   27205                en
# ...           ...                  ...     ...               ...
# 26512       26512             [27, 18]  488143                en
# 26513       26513             [18, 53]  485975                en
# 26514       26514         [14, 28, 12]  381231                en
# 26515       26515      [10751, 12, 28]  366854                en
# 26516       26516             [53, 27]  309885                en
#
#                                      original_title  popularity release_date  \
# 0      Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# ...

# %%
pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 1      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7, 2019                                 Dark Phoenix
# 3      4   May 1, 2015                      Avengers: Age of Ultron
# 4      5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5777  78  Dec 31, 2018                                       Red 11
# 5778  79   Apr 2, 1999                                    Following
# 5779  80  Jul 13, 2005                Return to the Land of Wonders
# 5780  81  Sep 29, 2015                         A Plague So Pleasant
# 5781  82   Aug 5, 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0         $425,000,000   $760,507,625  $2,776,345,279
# ...

# %%
df_a.head()
# Out:
#     movie_id          primary_title        original_title  start_year  \
# 0  tt1699720  !Women Art Revolution  Women Art Revolution        2010
# 1  tt2346170       #1 Serial Killer      #1 Serial Killer        2013
# 2  tt3120962                     #5                    #5        2013
# 3  tt8219776                     #5                    #5        2018
# 4  tt4470336             #50Fathers            #50Fathers        2015
#
#    runtime_minutes                    genres
# 0             83.0               Documentary
# 1             87.0                    Horror
# 2             68.0  Biography,Comedy,Fantasy
# 3              NaN               Documentary
# 4            132.0                    Comedy

# %%
df_a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %%
gross_df = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
gross_df.to_sql('title', conn, if_exists='replace', index=False)

# %%
Movie_Gross_DB = """
SELECT *
FROM title
"""

# %%
print(Movie_Gross_DB)
# Out:
# SELECT *
# FROM title

# %%
df = pd.read_csv('zippedData/bom.movie_gross.csv.gz', delimiter=';', encoding='utf-8')


conn = sqlite3.connect('data/im.db')


df.to_sql('title', conn, if_exists='replace', index=False)


cursor = conn.cursor()
query = "SELECT * FROM title"
result = cursor.execute(query).fetchall()
print(result)
# Out:
# [('Toy Story 3,BV,415000000.0,652000000,2010',), ('Alice in Wonderland (2010),BV,334200000.0,691300000,2010',), ('Harry Potter and the Deathly Hallows Part 1,WB,296000000.0,664300000,2010',), ('Inception,WB,292600000.0,535700000,2010',), ('Shrek Forever After,P/DW,238700000.0,513900000,2010',), ('The Twilight Saga: Eclipse,Sum.,300500000.0,398000000,2010',), ('Iron Man 2,Par.,312400000.0,311500000,2010',), ('Tangled,BV,200800000.0,391000000,2010',), ('Despicable Me,Uni.,251500000.0,291600000,2010',), ('How to Train Your Dragon,P/DW,217600000.0,277300000,2010',), ('Clash of the Titans (2010),WB,163200000.0,330000000,2010',), ('The Chronicles of Narnia: The Voyage of the Dawn Treader,Fox,104400000.0,311300000,2010',), ("The King's Speech,Wein.,135500000.0,275400000,2010",), ('Tron Legacy,BV,172100000.0,228000000,2010',), ('The Karate Kid,Sony,176600000.0,182500000,2010',), ('Prince of Persia: The Sands of Time,BV,90800000.0,245600000,2010',), ('Black Swan,FoxS,107000000.0,222400000,201
# ...

# %%
print(result[:10])
# Out:
# [('Toy Story 3,BV,415000000.0,652000000,2010',), ('Alice in Wonderland (2010),BV,334200000.0,691300000,2010',), ('Harry Potter and the Deathly Hallows Part 1,WB,296000000.0,664300000,2010',), ('Inception,WB,292600000.0,535700000,2010',), ('Shrek Forever After,P/DW,238700000.0,513900000,2010',), ('The Twilight Saga: Eclipse,Sum.,300500000.0,398000000,2010',), ('Iron Man 2,Par.,312400000.0,311500000,2010',), ('Tangled,BV,200800000.0,391000000,2010',), ('Despicable Me,Uni.,251500000.0,291600000,2010',), ('How to Train Your Dragon,P/DW,217600000.0,277300000,2010',)]

# %%
df_a = pd.read_sql(a,conn)

# %%
df_a.head()
# Out:
#     movie_id          primary_title        original_title  start_year  \
# 0  tt1699720  !Women Art Revolution  Women Art Revolution        2010
# 1  tt2346170       #1 Serial Killer      #1 Serial Killer        2013
# 2  tt3120962                     #5                    #5        2013
# 3  tt8219776                     #5                    #5        2018
# 4  tt4470336             #50Fathers            #50Fathers        2015
#
#    runtime_minutes                    genres
# 0             83.0               Documentary
# 1             87.0                    Horror
# 2             68.0  Biography,Comedy,Fantasy
# 3              NaN               Documentary
# 4            132.0                    Comedy

# %%
movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz', header=0)


print(movie_gross.head())
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#   foreign_gross  year
# 0     652000000  2010
# 1     691300000  2010
# 2     664300000  2010
# 3     535700000  2010
# 4     513900000  2010

# %%
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %%
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('movie_basics',), ('directors',), ('known_for',), ('movie_akas',), ('movie_ratings',), ('persons',), ('principals',), ('writers',), ('movie_gross_table',), ('title',)]

# %%
# Read the CSV file
movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# Create a connection to the SQLite database
conn = sqlite3.connect('data/im.db')

# Create a table from the movie_gross DataFrame
movie_gross.to_sql('movie_gross_table', conn, if_exists='replace', index=False)

# Define the SQL query to join the two tables
sql_query = '''
    SELECT mb.*, mg.*, mr.*, LOWER(mb.primary_title) as lw_ptitle, LOWER(mg.title) as lw_title,
    LOWER(TRIM(REPLACE(mb.primary_title,':',''))) as a,
    LOWER(TRIM(REPLACE(mg.title,':',''))) as b
    FROM movie_basics mb
    LEFT JOIN movie_ratings mr
    ON mb.movie_id = mr.movie_id
    LEFT JOIN movie_gross_table mg 
    
    ON LOWER(TRIM(REPLACE(mb.primary_title,':',''))) = LOWER(TRIM(REPLACE(mg.title,':','')))
'''


# Execute the SQL query and fetch the results
results = pd.read_sql(sql_query, conn)

# Close the database connection
conn.close()

# Print the column names in the joined table
print(results.columns)
# Out:
# Index(['movie_id', 'primary_title', 'original_title', 'start_year',
#        'runtime_minutes', 'genres', 'title', 'studio', 'domestic_gross',
#        'foreign_gross', 'year', 'movie_id', 'averagerating', 'numvotes',
#        'lw_ptitle', 'lw_title', 'a', 'b'],
#       dtype='object')

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146146 entries, 0 to 146145
# Data columns (total 18 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   movie_id         146146 non-null  object
#  1   primary_title    146146 non-null  object
#  2   original_title   146125 non-null  object
#  3   start_year       146146 non-null  int64
#  4   runtime_minutes  114407 non-null  float64
#  5   genres           140738 non-null  object
#  6   title            3506 non-null    object
#  7   studio           3503 non-null    object
#  8   domestic_gross   3481 non-null    float64
#  9   foreign_gross    2117 non-null    object
#  10  year             3506 non-null    float64
#  11  movie_id         73858 non-null   object
#  12  averagerating    73858 non-null   float64
#  13  numvotes         73858 non-null   float64
#  14  lw_ptitle        146146 non-null  object
#  15  lw_title         3506 non-null    object
# ...

# %%
results.to_csv('joined_data.csv', index=False)

# %%
results_drop = results.dropna(subset=['b'])

# %%
results_drop = results_drop.dropna(subset=['domestic_gross'])

# %%
results_drop = results_drop.dropna(subset=['averagerating'])

# %%
results_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3129 entries, 38 to 146080
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   movie_id         3129 non-null   object
#  1   primary_title    3129 non-null   object
#  2   original_title   3129 non-null   object
#  3   start_year       3129 non-null   int64
#  4   runtime_minutes  3080 non-null   float64
#  5   genres           3122 non-null   object
#  6   title            3129 non-null   object
#  7   studio           3128 non-null   object
#  8   domestic_gross   3129 non-null   float64
#  9   foreign_gross    1875 non-null   object
#  10  year             3129 non-null   float64
#  11  movie_id         3129 non-null   object
#  12  averagerating    3129 non-null   float64
#  13  numvotes         3129 non-null   float64
#  14  lw_ptitle        3129 non-null   object
#  15  lw_title         3129 non-null   object
# ...

# %%
results_drop.to_csv('joined_data_final.csv', index=False)

# %%
x = results_drop['averagerating']
y = results_drop['domestic_gross']

# %%
    from scipy.stats import pearsonr
    corr, _ = pearsonr(x, y)
    print('Pearson correlation: %.3f' % corr)
# Out:
# Pearson correlation: 0.124

# %%
plt.scatter(x, y)
plt.xlabel('Average Rating')
plt.ylabel('Domestic Gross')
plt.title('Relationship between Average Rating and Domestic Gross')
plt.show()

# %%
# Calculate the coefficients of the polynomial fit
coefficients = np.polyfit(x, y, 1)
slope, intercept = coefficients

# Plot the scatter plot
plt.scatter(x, y)

# Plot the trend line
plt.plot(x, slope * x + intercept, color='red')

# Add labels and title
plt.xlabel('Rating')
plt.ylabel('Gross Income')
plt.title('Rating vs. Gross Income')

# Show the plot
plt.show()

# %%
# create figure and axes objects
fig, ax = plt.subplots(figsize=(8, 6))

# plot the data points
sns.regplot(x=x, y=y, ax=ax, scatter_kws={'s': 20}, line_kws={'linewidth': 2})

# set axis labels and title
ax.set_xlabel('Average Rating')
ax.set_ylabel('Domestic Gross')
ax.set_title('Correlation between Movie Ratings and Gross Income')

# show the plot
plt.show()

# %%
results_cleaned_over1 = results_drop.loc[results_drop['domestic_gross'] >= 100000000]

# %%
x = results_cleaned_over1['averagerating']
y = results_cleaned_over1['domestic_gross']

# %%
# create figure and axes objects
fig, ax = plt.subplots(figsize=(8, 6))

# plot the data points
sns.regplot(x=x, y=y, ax=ax, scatter_kws={'s': 20}, line_kws={'linewidth': 2})

# set axis labels and title
ax.set_xlabel('Average Rating')
ax.set_ylabel('Domestic Gross ($)')
ax.set_title('Correlation between Movie Ratings and Gross Income')
# ax.set_ylim(bottom=1000000)

# set y-axis formatter to show more digits
ax.yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

# show the plot
plt.show()

# %%
results_cleaned_over1 = results_drop.loc[results_drop['domestic_gross'] >= 200000000]


# create a scatter plot with a trend line and correlation coefficient
sns.regplot(x="averagerating", y="domestic_gross", data=results_cleaned_over1, scatter_kws={'s': 20}, line_kws={'linewidth': 2})

# set axis labels and title
plt.xlabel('Average Rating')
plt.ylabel('Domestic Gross ($)')
plt.title('Correlation between Movie Ratings and Gross Income')

# show the correlation coefficient
corr_coef = results_cleaned_over1['averagerating'].corr(results_cleaned_over1['domestic_gross'])
plt.text(3, 0.9e9, f"Correlation coefficient = {corr_coef:.2f}", fontsize=12)

# set y-axis formatter to show more digits
plt.gca().yaxis.set_major_formatter(StrMethodFormatter('{x:,.0f}'))

# remove excess space around the plot
plt.tight_layout()

# show the plot
plt.show()

# %%
df.np.corrcoef(['array1'],['array2'])
